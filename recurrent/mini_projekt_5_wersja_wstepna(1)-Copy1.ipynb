# %% [markdown]
# ### Potrzebne importy, wstępna konfiguracja

# %%
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

from torch.utils.data import DataLoader
from collections import Counter

from torch.utils.data import Dataset
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence

# %%
device = torch.device('cuda') # torch.device('cpu')
device
# Out:
# device(type='cuda')

# %%
rng = np.random.default_rng(73512)

# %% [markdown]
# ### Przygotowanie danych (wraz z paddingiem)

# %%
train_data = pd.read_pickle('train.pkl')
test_data = pd.read_pickle('test_no_target.pkl')

# %%
all_elements = []
for i in train_data:
    for j in i[0]:
        all_elements.append(j)
elements_count = Counter(all_elements)
print(elements_count)
# df.plot(kind="bar")
# Out:
# Counter({12.0: 113916, 92.0: 63517, 47.0: 44650, 0.0: 43486, 44.0: 35785, 28.0: 33661, 159.0: 29503, 124.0: 29464, 13.0: 29334, 78.0: 26965, 45.0: 21287, 60.0: 21007, 112.0: 20988, 8.0: 19276, 88.0: 19203, 15.0: 18982, 79.0: 17975, 156.0: 17884, 5.0: 17278, 76.0: 17187, 125.0: 16829, 77.0: 16378, 33.0: 14950, 80.0: 14936, 172.0: 14740, 190.0: 14488, 145.0: 13366, -1.0: 13273, 127.0: 12150, 144.0: 11763, 30.0: 11753, 119.0: 11441, 73.0: 11298, 20.0: 11137, 180.0: 11127, 158.0: 11085, 93.0: 10393, 41.0: 10239, 32.0: 9622, 64.0: 9319, 157.0: 9297, 140.0: 8950, 68.0: 8548, 100.0: 8490, 185.0: 7563, 36.0: 7527, 111.0: 7374, 121.0: 7301, 14.0: 7208, 148.0: 7092, 2.0: 6957, 1.0: 6890, 132.0: 6799, 7.0: 6554, 46.0: 6418, 40.0: 6279, 120.0: 6215, 37.0: 6029, 95.0: 5960, 114.0: 5853, 65.0: 5732, 117.0: 5507, 67.0: 5502, 34.0: 5373, 160.0: 4825, 31.0: 4799, 146.0: 4752, 71.0: 4664, 152.0: 4614, 126.0: 4598, 29.0: 4461, 141.0: 4436, 110.0: 4390, 69.0: 4297, 82.0: 4253, 66.0: 4190, 175.0: 4154, 108.0: 4067, 3.0: 3990, 39.0: 3981, 153.0: 3876, 4.0: 3754, 48.0: 3637, 128.0: 3607, 9.0: 3566, 52.0: 3444, 72.0: 3263, 6.0: 3259, 56.0: 3222, 25.0: 3177, 178.0: 3164, 42.0: 3164, 176.0: 3159, 116.0: 3130, 74.0: 3125, 151.0: 3070, 38.0: 2816, 109.0: 2738, 24.0: 2714, 106.0: 2684, 188.0: 2641, 61.0: 2586, 191.0: 2562, 43.0: 2556, 81.0: 2544, 113.0: 2396, 162.0: 2344, 84.0: 2336, 189.0: 2306, 50.0: 2283, 21.0: 2264, 10.0: 2120, 18.0: 2083, 23.0: 2008, 16.0: 2006, 89.0: 1969, 142.0: 1961, 149.0: 1938, 94.0: 1934, 17.0: 1860, 63.0: 1807, 11.0: 1792, 137.0: 1754, 164.0: 1733, 183.0: 1698, 27.0: 1688, 98.0: 1599, 179.0: 1538, 35.0: 1489, 168.0: 1419, 173.0: 1360, 62.0: 1327, 154.0: 1319, 87.0: 1310, 96.0: 1310, 26.0: 1127, 167.0: 1091, 90.0: 1066, 136.0: 973, 143.0: 968, 174.0: 966, 177.0: 963, 53.0: 941, 58.0: 938, 57.0: 903, 55.0: 882, 161.0: 823, 122.0: 800, 181.0: 730, 49.0: 695, 105.0: 687, 97.0: 683, 22.0: 663, 135.0: 628, 104.0: 614, 129.0: 582, 103.0: 550, 85.0: 540, 147.0: 514, 118.0: 425, 51.0: 365, 138.0: 301, 134.0: 272, 131.0: 267, 150.0: 234, 70.0: 224, 91.0: 221, 184.0: 213, 19.0: 209, 130.0: 170, 54.0: 100, 102.0: 93, 165.0: 81, 186.0: 78, 101.0: 70, 133.0: 64, 169.0: 63, 115.0: 56, 107.0: 50, 163.0: 33, 170.0: 33, 123.0: 6})

# %%
print(f"Minimalna wartość wśród danych: {min(all_elements)}")
print(f"Maksymalna wartość wśród danych: {max(all_elements)}")
# Out:
# Minimalna wartość wśród danych: -1.0
# Maksymalna wartość wśród danych: 191.0

# %%
class VariableLenDataset(Dataset):
    def __init__(self, in_data, target):
        self.data = [(torch.Tensor(x).float(), torch.tensor(y).long()) for x, y in zip(in_data, target)]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        in_data, target = self.data[idx]
        return in_data, target

    def __print__(self):
        print(self.data)

# %%
data = [i[0] for i in train_data]
classes = [i[1] for i in train_data]

# %%
len([i for i in classes if i == 0])
# Out:
# 1630

# %%
train_indices = rng.random(len(data)) > 0.3
train_indices
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
classes_train = [ x for i, x in enumerate(classes) if train_indices[i]]
classes_valid = [ x for i, x in enumerate(classes) if not train_indices[i]]
data_train = [ x for i, x in enumerate(data) if train_indices[i]]
data_valid = [ x for i, x in enumerate(data) if not train_indices[i]]

# %%
train_set = VariableLenDataset(data_train,
                               classes_train)
valid_set = VariableLenDataset(data_valid,
                               classes_valid)
# train_set.__print__()
train_set.__getitem__(1)
# Out:
# (tensor([ -1.,  -1., 144.,  ...,  32.,  -1.,  -1.]), tensor(0))

# %%
pad = -2

def pad_collate(batch, pad_value=pad):

    xx, yy = zip(*batch)
    x_lens = [len(x) for x in xx]
    xx_pad = pad_sequence(xx, batch_first=True, padding_value=pad_value)
    yy_tensor = torch.stack(yy)

    return xx_pad, yy_tensor, x_lens

# %%
def compute_classes_weights(classes):
    classes_count = []
    classes_count.append(len([i for i in classes if i == 0]))
    classes_count.append(len([i for i in classes if i == 1]))
    classes_count.append(len([i for i in classes if i == 2]))
    classes_count.append(len([i for i in classes if i == 3]))
    classes_count.append(len([i for i in classes if i == 4]))
    classes_count = torch.tensor(classes_count)
    weights = 1. / classes_count.float()
    sample_weights = torch.tensor([weights[t] for t in classes])
    return sample_weights

# %%
train_loader = DataLoader(train_set, batch_size=64, collate_fn=pad_collate, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=64, collate_fn=pad_collate, shuffle=True)

# %% [markdown]
# ### Model (wstępny)

# %%
class LSTM_Seq_Regressor(nn.Module):

    def __init__(self, input_size, hidden_size, num_layers, out_size, bidirectional=False, drop_out=0):
        super().__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.proj_size = out_size
        if bidirectional:
            self.bidirectional = 2
        else:
            self.bidirectional =1
        self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_size, num_layers = num_layers, 
                            proj_size = out_size, bidirectional = bidirectional, dropout=drop_out)
        self.fc2 = nn.Linear(hidden_size, out_size)

    def init_hidden(self, batch_size):
        hidden = torch.zeros(self.num_layers*self.bidirectional, batch_size, self.proj_size)
        state = torch.zeros(self.num_layers*self.bidirectional, batch_size, self.hidden_size)
        return hidden, state

    def forward(self, x, hidden):
        all_outputs, hidden = self.lstm(x, hidden)
        return all_outputs, hidden

# %%
def eval(loader, net):

    correct_pred = 0
    total_pred = 0
    net.eval()
    loss_fun = nn.CrossEntropyLoss()
    with torch.no_grad():
        for x, targets, x_len in loader:
            # images = images.to(device)
            x = x.to(device).unsqueeze(2)
            targets = targets.to(device)

            hidden, state = model.init_hidden(x.size(0))
            hidden, state = hidden.to(device), state.to(device)

            x_packed = pack_padded_sequence(x, x_len, batch_first=True, enforce_sorted=False)
            preds_packed, _ = model(x_packed, (hidden, state))
            preds, pred_len = pad_packed_sequence(preds_packed, batch_first=True, padding_value=pad)

            preds = preds.squeeze(2)
            last_outputs = []
            for i, length in enumerate(pred_len):
                last_outputs.append(preds[i, length -1 , :])
            last_outputs = torch.stack(last_outputs)
            loss = loss_fun(last_outputs, targets)

            _, predictions = torch.max(last_outputs, 1)
            # collect the correct predictions for each class
            for label, prediction in zip(targets, predictions):
                if label == prediction:
                    correct_pred += 1
                total_pred += 1
    return correct_pred/total_pred, loss

# %%
model = LSTM_Seq_Regressor(1, 100, 1, 5).to(device)
model
# Out:
# LSTM_Seq_Regressor(
#   (lstm): LSTM(1, 100, proj_size=5)
#   (fc2): Linear(in_features=100, out_features=5, bias=True)
# )

# %%
def train_model(model, train_loader, valid_loader, train_loss, valid_loss, train_acc, valid_acc, learning_rate=0.001, epoch_number=200):
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=0.01)
    loss_fun = nn.CrossEntropyLoss()

    # Training loop
    for epoch in range(epoch_number):
        for x, targets, x_len in train_loader:
            # print(f"Trening: {x} oraz {targets}")
            model.train()
            x = x.to(device).unsqueeze(2)
            targets = targets.to(device)
    
            hidden, state = model.init_hidden(x.size(0))
            hidden, state = hidden.to(device), state.to(device)
    
            x_packed = pack_padded_sequence(x, x_len, batch_first=True, enforce_sorted=False)
            preds_packed, _ = model(x_packed, (hidden, state))
            preds, pred_len = pad_packed_sequence(preds_packed, batch_first=True, padding_value=pad)
    
            preds = preds.squeeze(2)
            last_outputs = []
            for i, length in enumerate(pred_len):
                last_outputs.append(preds[i, length -1 , :])
            last_outputs = torch.stack(last_outputs)
            optimizer.zero_grad()
            # mask = targets != pad
            # print(mask)
            loss = loss_fun(last_outputs, targets)
            loss.backward()
            optimizer.step()
        if epoch % 10 == 0:
            acc_valid, loss_valid = eval(valid_loader, model)
            acc_train, loss_train = eval(train_loader, model)
            train_loss.append(loss_train)
            valid_loss.append(loss_valid)
            train_acc.append(acc_train)
            valid_acc.append(acc_valid)
            print(f"Epoch: {epoch}, loss train: {loss_train.item():.3}, loss valid: {loss_valid}")
            print(f'Accuracy train: {acc_train}')
            print(f'Accuracy valid: {acc_valid}')

# %%
def plot_metrics(train_loss, valid_loss, train_acc, valid_acc):
    iters_losses = [i for i in range(len(train_loss))]
    iters_acc = [i for i in range(len(train_acc))]
    
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.title("Training Curve")
    plt.plot(iters_losses, train_loss, label="Train")
    plt.plot(iters_losses, valid_loss, label="Valid")
    plt.legend(loc='best')
    plt.ylabel("Loss")
    
    plt.subplot(1,2,2)
    plt.title("Training Curve")
    plt.plot(iters_acc, train_acc, label="Train")
    plt.plot(iters_acc, valid_acc, label="Validation")
    plt.xlabel("Iterations")
    plt.ylabel("Training Accuracy")
    plt.legend(loc='best')
    
    plt.show()
    
    
    print("Final Training Accuracy: {}".format(train_acc[-1]))
    print("Final Validation Accuracy: {}".format(valid_acc[-1]))

# %% [markdown]
# ## Dla zestackowanego modułu LSTM

# %%
model = LSTM_Seq_Regressor(1, 10, 2, 5, bidirectional=True).to(device)
train_loss = []
valid_loss = []
train_acc = []
valid_acc = []
train_model(model, train_loader, valid_loader, train_loss, valid_loss, train_acc, valid_acc, learning_rate=0.001)
# Out:
# Epoch: 0, loss train: 2.2, loss valid: 2.160252332687378
# Accuracy train: 0.5399802566633761
# Accuracy valid: 0.5410733844468785
# Epoch: 10, loss train: 1.16, loss valid: 1.3635046482086182
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 20, loss train: 1.22, loss valid: 1.20574152469635
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 30, loss train: 1.33, loss valid: 1.2373971939086914
# Accuracy train: 0.5839091806515301
# Accuracy valid: 0.592552026286966
# Epoch: 40, loss train: 1.27, loss valid: 1.1390950679779053
# Accuracy train: 0.6016781836130306
# Accuracy valid: 0.6002190580503833
# Epoch: 50, loss train: 1.12, loss valid: 0.996810257434845
# Accuracy train: 0.6066140177690029
# Accuracy valid: 0.6056955093099672
# Epoch: 60, loss train: 0.929, loss valid: 0.9402056336402893
# Accuracy train: 0.6100691016781836
# Accuracy valid: 0.6024096385542169
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 6
#       4 train_acc = []
#       5 valid_acc = []
# ----> 6 train_model(model, train_loader, valid_loader, train_loss, valid_loss, train_acc, valid_acc, learning_rate=0.001)
#
# Cell In[30], line 29, in train_model(model, train_loader, valid_loader, train_loss, valid_loss, train_acc, valid_acc, learning_rate, epoch_number)
#      26     # mask = targets != pad
#      27     # print(mask)
#      28     loss = loss_fun(last_outputs, targets)
# ---> 29     loss.backward()
#      30     optimizer.step()
#      31 if epoch % 10 == 0:
#
# File /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %% [markdown]
# # Ustalanie odpowiedniego samplingu

# %% [markdown]
# ### Sampling za pomocą WeighteRandomSampler - wielkość zbioru nie zmieniona
#
# Wielkość zbiory nie jest zmieniona, każda próbka ma przypisane prawdopodobieństwo, żeby próbki każdej klasy były wybieranie odpowiednio często.

# %%
samples_weights_train = compute_classes_weights(classes_train)
samples_weights_valid = compute_classes_weights(classes_valid)

# %%
sampler_train = torch.utils.data.WeightedRandomSampler(samples_weights_train, len(samples_weights_train), replacement=True)
sampler_valid = torch.utils.data.WeightedRandomSampler(samples_weights_valid, len(samples_weights_valid), replacement=True)
train_loader = DataLoader(train_set, batch_size=64, collate_fn=pad_collate, sampler=sampler_train)
valid_loader = DataLoader(valid_set, batch_size=64, collate_fn=pad_collate, shuffle=True)

# %% [markdown]
# Hidden size = 100

# %%
model = LSTM_Seq_Regressor(1, 100, 1, 5).to(device)
model
# Out:
# LSTM_Seq_Regressor(
#   (lstm): LSTM(1, 100, proj_size=5)
#   (fc2): Linear(in_features=100, out_features=5, bias=True)
# )

# %%
train_loss = []
valid_loss = []
train_acc = []
valid_acc = []

# %%
train_model(model, train_loader, valid_loader, train_loss, valid_loss, train_acc, valid_acc)
# Out:
# Epoch: 0, loss train: 1.55, loss valid: 1.6545504331588745
# Accuracy train: 0.32576505429417574
# Accuracy valid: 0.24644030668127054
# Epoch: 10, loss train: 1.23, loss valid: 1.2522075176239014
# Accuracy train: 0.5029615004935835
# Accuracy valid: 0.4370208105147864
# Epoch: 20, loss train: 0.927, loss valid: 1.230544090270996
# Accuracy train: 0.577492596248766
# Accuracy valid: 0.5859802847754655
# Epoch: 30, loss train: 0.894, loss valid: 0.8028404116630554
# Accuracy train: 0.6268509378084897
# Accuracy valid: 0.628696604600219
# Epoch: 40, loss train: 0.918, loss valid: 1.0791187286376953
# Accuracy train: 0.6327739387956565
# Accuracy valid: 0.6440306681270537
# Epoch: 50, loss train: 0.958, loss valid: 0.7647656202316284
# Accuracy train: 0.7033563672260612
# Accuracy valid: 0.628696604600219
# Epoch: 60, loss train: 0.671, loss valid: 0.9057462811470032
# Accuracy train: 0.7181638696939783
# Accuracy valid: 0.6308871851040526
# Epoch: 70, loss train: 0.639, loss valid: 0.5782299637794495
# Accuracy train: 0.7541954590325765
# Accuracy valid: 0.6210295728368017
# Epoch: 80, loss train: 0.684, loss valid: 1.0074100494384766
# Accuracy train: 0.7541954590325765
# Accuracy valid: 0.656078860898138
# Epoch: 90, loss train: 0.853, loss valid: 1.0446789264678955
# Accuracy train: 0.769990128331688
# Accuracy valid: 0.6385542168674698
# Epoch: 100, loss train: 0.702, loss valid: 0.6269821524620056
# Accuracy train: 0.7828232971372162
# Accuracy valid: 0.6538882803943045
# Epoch: 110, loss train: 0.491, loss valid: 0.6569345593452454
# Accuracy train: 0.8188548864758144
# Accuracy valid: 0.6725082146768894
# Epoch: 120, loss train: 0.474, loss valid: 0.7624771595001221
# Accuracy train: 0.7912142152023692
# Accuracy valid: 0.6506024096385542
# Epoch: 130, loss train: 0.583, loss valid: 1.1906602382659912
# Accuracy train: 0.792694965449161
# Accuracy valid: 0.6527929901423878
# Epoch: 140, loss train: 0.359, loss valid: 1.5274722576141357
# Accuracy train: 0.8302073050345509
# Accuracy valid: 0.6746987951807228
# Epoch: 150, loss train: 0.434, loss valid: 1.0918948650360107
# Accuracy train: 0.7951628825271471
# Accuracy valid: 0.6276013143483024
# Epoch: 160, loss train: 0.461, loss valid: 0.6186469197273254
# Accuracy train: 0.832675222112537
# Accuracy valid: 0.6933187294633077
# Epoch: 170, loss train: 1.23, loss valid: 1.2823550701141357
# Accuracy train: 0.5765054294175715
# Accuracy valid: 0.488499452354874
# Epoch: 180, loss train: 0.749, loss valid: 1.1322619915008545
# Accuracy train: 0.730009871668312
# Accuracy valid: 0.5969331872946331
# Epoch: 190, loss train: 0.529, loss valid: 1.3138517141342163
# Accuracy train: 0.7778874629812438
# Accuracy valid: 0.6615553121577218

# %%
train_loss = [x.cpu() for x in train_loss]
valid_loss = [x.cpu() for x in valid_loss]

# %%
plot_metrics(train_loss, valid_loss, train_acc, valid_acc)
# Out:
# Final Training Accuracy: 0.7778874629812438
# Final Validation Accuracy: 0.6615553121577218

# %% [markdown]
# ### Z dodanym drop outem

# %%
model = LSTM_Seq_Regressor(1, 100, 1, 5, drop_out=0.3).to(device)
model
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.3 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# LSTM_Seq_Regressor(
#   (lstm): LSTM(1, 100, proj_size=5, dropout=0.3)
#   (fc2): Linear(in_features=100, out_features=5, bias=True)
# )

# %%
train_loss = []
valid_loss = []
train_acc = []
valid_acc = []

# %%
train_model(model, train_loader, valid_loader, train_loss, valid_loss, train_acc, valid_acc)
# Out:
# Epoch: 0, loss train: 1.58, loss valid: 1.5740151405334473
# Accuracy train: 0.2917077986179664
# Accuracy valid: 0.15005476451259583
# Epoch: 10, loss train: 1.26, loss valid: 1.318078637123108
# Accuracy train: 0.4817374136229023
# Accuracy valid: 0.48083242059145676
# Epoch: 40, loss train: 0.889, loss valid: 0.9382912516593933
# Accuracy train: 0.6554787759131293
# Accuracy valid: 0.588170865279299
# Epoch: 50, loss train: 0.902, loss valid: 0.9624391198158264
# Accuracy train: 0.6539980256663376
# Accuracy valid: 0.6254107338444688
# Epoch: 60, loss train: 0.787, loss valid: 0.6422419548034668
# Accuracy train: 0.6846001974333662
# Accuracy valid: 0.619934282584885
# Epoch: 70, loss train: 0.641, loss valid: 1.3497934341430664
# Accuracy train: 0.7507403751233959
# Accuracy valid: 0.624315443592552
# Epoch: 80, loss train: 0.746, loss valid: 0.9073887467384338
# Accuracy train: 0.7576505429417572
# Accuracy valid: 0.6538882803943045
# Epoch: 90, loss train: 0.761, loss valid: 1.3995146751403809
# Accuracy train: 0.6678183613030603
# Accuracy valid: 0.5542168674698795
# Epoch: 100, loss train: 0.759, loss valid: 1.1551467180252075
# Accuracy train: 0.7941757156959526
# Accuracy valid: 0.6418400876232202
# Epoch: 110, loss train: 0.583, loss valid: 0.8710726499557495
# Accuracy train: 0.7556762092793682
# Accuracy valid: 0.6582694414019715
# Epoch: 120, loss train: 0.56, loss valid: 0.728606641292572
# Accuracy train: 0.7502467917077986
# Accuracy valid: 0.6703176341730559
# Epoch: 130, loss train: 0.755, loss valid: 1.4966483116149902
# Accuracy train: 0.7828232971372162
# Accuracy valid: 0.6703176341730559
# Epoch: 140, loss train: 0.446, loss valid: 0.7718387842178345
# Accuracy train: 0.8005923000987167
# Accuracy valid: 0.6670317634173056
# Epoch: 150, loss train: 0.618, loss valid: 1.2689073085784912
# Accuracy train: 0.7931885488647581
# Accuracy valid: 0.6078860898138007
# Epoch: 160, loss train: 0.419, loss valid: 1.126997470855713
# Accuracy train: 0.7951628825271471
# Accuracy valid: 0.6790799561883899
# Epoch: 170, loss train: 0.807, loss valid: 1.8019301891326904
# Accuracy train: 0.7492596248766041
# Accuracy valid: 0.6538882803943045
# Epoch: 180, loss train: 0.372, loss valid: 0.9669762849807739
# Accuracy train: 0.7798617966436328
# Accuracy valid: 0.6757940854326396
# Epoch: 190, loss train: 0.989, loss valid: 1.8278727531433105
# Accuracy train: 0.5982230997038499
# Accuracy valid: 0.5312157721796276

# %%
train_loss = [x.cpu() for x in train_loss]
valid_loss = [x.cpu() for x in valid_loss]

# %%
plot_metrics(train_loss, valid_loss, train_acc, valid_acc)
# Out:
# Final Training Accuracy: 0.5982230997038499
# Final Validation Accuracy: 0.5312157721796276

# %% [markdown]
# ### Dla undersamplingu

# %%
sampler_train = torch.utils.data.WeightedRandomSampler(samples_weights_train, len(samples_weights_train), replacement=False)
sampler_valid = torch.utils.data.WeightedRandomSampler(samples_weights_valid, len(samples_weights_valid), replacement=False)
train_loader = DataLoader(train_set, batch_size=64, collate_fn=pad_collate, sampler=sampler_train)
valid_loader = DataLoader(valid_set, batch_size=64, collate_fn=pad_collate, shuffle=True)

# %%
model = LSTM_Seq_Regressor(1, 100, 1, 5, drop_out=0.3).to(device)
model
# Out:
# LSTM_Seq_Regressor(
#   (lstm): LSTM(1, 100, proj_size=5, dropout=0.3)
#   (fc2): Linear(in_features=100, out_features=5, bias=True)
# )

# %%
train_loss = []
valid_loss = []
train_acc = []
valid_acc = []

# %%
train_model(model, train_loader, valid_loader, train_loss, valid_loss, train_acc, valid_acc)
# Out:
# Epoch: 0, loss train: 0.254, loss valid: 0.9841160774230957
# Accuracy train: 0.5888450148075025
# Accuracy valid: 0.5991237677984665
# Epoch: 10, loss train: 0.271, loss valid: 1.1886627674102783
# Accuracy train: 0.6436327739387957
# Accuracy valid: 0.6396495071193866
# Epoch: 20, loss train: 0.33, loss valid: 1.1868410110473633
# Accuracy train: 0.6520236920039487
# Accuracy valid: 0.6473165388828039
# Epoch: 30, loss train: 0.231, loss valid: 1.101635217666626
# Accuracy train: 0.6436327739387957
# Accuracy valid: 0.6429353778751369
# Epoch: 40, loss train: 0.236, loss valid: 1.6211743354797363
# Accuracy train: 0.6599210266535045
# Accuracy valid: 0.651697699890471
# Epoch: 50, loss train: 0.308, loss valid: 0.9665952324867249
# Accuracy train: 0.6658440276406713
# Accuracy valid: 0.6549835706462213

# %%
train_loss = [x.cpu() for x in train_loss]
valid_loss = [x.cpu() for x in valid_loss]

# %%
plot_metrics(train_loss, valid_loss, train_acc, valid_acc)

# %% [markdown]
# ### Dla modelu "bidirectional"

# %%
model = LSTM_Seq_Regressor(1, 100, 1, 5, bidirectional=True, drop_out=0.01).to(device)
train_loss = []
valid_loss = []
train_acc = []
valid_acc = []
train_model(model, train_loader, valid_loader, train_loss, valid_loss, train_acc, valid_acc, learning_rate=0.001)

# %%
model = LSTM_Seq_Regressor(1, 100, 1, 5).to(device)
train_loss = []
valid_loss = []
train_acc = []
valid_acc = []
train_model(model, train_loader, valid_loader, train_loss, valid_loss, train_acc, valid_acc, learning_rate=0.0001)
# Out:
# Epoch: 0, loss train: 1.61, loss valid: 1.5999842882156372
# Accuracy train: 0.09081934846989141
# Accuracy valid: 0.09419496166484119
# Epoch: 1, loss train: 1.56, loss valid: 1.5440617799758911
# Accuracy train: 0.1895360315893386
# Accuracy valid: 0.22343921139101863
# Epoch: 2, loss train: 1.53, loss valid: 1.478910207748413
# Accuracy train: 0.5212240868706811
# Accuracy valid: 0.5224534501642936
# Epoch: 3, loss train: 1.48, loss valid: 1.4822072982788086
# Accuracy train: 0.5429417571569596
# Accuracy valid: 0.547645125958379
# Epoch: 4, loss train: 1.46, loss valid: 1.3822956085205078
# Accuracy train: 0.5468904244817374
# Accuracy valid: 0.5531215772179627
# Epoch: 5, loss train: 1.44, loss valid: 1.48439359664917
# Accuracy train: 0.5463968410661402
# Accuracy valid: 0.5553121577217963
# Epoch: 6, loss train: 1.45, loss valid: 1.4844703674316406
# Accuracy train: 0.5493583415597236
# Accuracy valid: 0.5553121577217963
# Epoch: 7, loss train: 1.31, loss valid: 1.4276914596557617
# Accuracy train: 0.5513326752221125
# Accuracy valid: 0.556407447973713
# Epoch: 8, loss train: 1.29, loss valid: 1.415647268295288
# Accuracy train: 0.5513326752221125
# Accuracy valid: 0.5575027382256298
# Epoch: 9, loss train: 1.36, loss valid: 1.3105359077453613
# Accuracy train: 0.552319842053307
# Accuracy valid: 0.5585980284775466
# Epoch: 10, loss train: 1.35, loss valid: 1.417019009590149
# Accuracy train: 0.552319842053307
# Accuracy valid: 0.5585980284775466
# Epoch: 11, loss train: 1.32, loss valid: 1.420029878616333
# Accuracy train: 0.5528134254689042
# Accuracy valid: 0.5585980284775466
# Epoch: 12, loss train: 1.29, loss valid: 1.4225356578826904
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5585980284775466
# Epoch: 13, loss train: 1.4, loss valid: 1.5206010341644287
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5585980284775466
# Epoch: 14, loss train: 1.29, loss valid: 1.3488264083862305
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 15, loss train: 1.19, loss valid: 1.3686885833740234
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 16, loss train: 1.19, loss valid: 0.8035386800765991
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 17, loss train: 1.41, loss valid: 1.347631812095642
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 18, loss train: 1.42, loss valid: 1.1851028203964233
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 19, loss train: 1.27, loss valid: 1.0394322872161865
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 20, loss train: 1.39, loss valid: 1.498548984527588
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 21, loss train: 1.26, loss valid: 1.2095693349838257
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 22, loss train: 1.26, loss valid: 1.10061514377594
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 23, loss train: 1.25, loss valid: 1.1615341901779175
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 24, loss train: 1.17, loss valid: 1.1583614349365234
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 25, loss train: 1.34, loss valid: 1.3521883487701416
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 26, loss train: 1.12, loss valid: 0.8265992999076843
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 27, loss train: 1.15, loss valid: 0.921600341796875
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 28, loss train: 1.22, loss valid: 1.4474817514419556
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 29, loss train: 1.26, loss valid: 1.2848663330078125
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 30, loss train: 1.23, loss valid: 1.3791478872299194
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 31, loss train: 1.15, loss valid: 1.5191683769226074
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 32, loss train: 1.28, loss valid: 1.2408792972564697
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 33, loss train: 1.19, loss valid: 1.2414054870605469
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 34, loss train: 1.21, loss valid: 1.3184006214141846
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 35, loss train: 1.16, loss valid: 1.1912282705307007
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 36, loss train: 1.25, loss valid: 1.0637301206588745
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 37, loss train: 1.15, loss valid: 1.2107943296432495
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 38, loss train: 1.33, loss valid: 1.6438565254211426
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 39, loss train: 1.28, loss valid: 1.1298483610153198
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 40, loss train: 1.27, loss valid: 1.2978451251983643
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 41, loss train: 1.21, loss valid: 1.3699960708618164
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 42, loss train: 1.15, loss valid: 1.2925429344177246
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 43, loss train: 1.1, loss valid: 1.3851349353790283
# Accuracy train: 0.56071076011846
# Accuracy valid: 0.5596933187294633
# Epoch: 44, loss train: 1.2, loss valid: 0.8407631516456604
# Accuracy train: 0.5602171767028628
# Accuracy valid: 0.5596933187294633
# Epoch: 45, loss train: 1.18, loss valid: 1.3635621070861816
# Accuracy train: 0.5612043435340572
# Accuracy valid: 0.56078860898138
# Epoch: 46, loss train: 1.07, loss valid: 1.1737390756607056
# Accuracy train: 0.5631786771964462
# Accuracy valid: 0.5618838992332968
# Epoch: 47, loss train: 1.13, loss valid: 0.9859916567802429
# Accuracy train: 0.5651530108588352
# Accuracy valid: 0.5629791894852135
# Epoch: 48, loss train: 1.34, loss valid: 1.0850950479507446
# Accuracy train: 0.5735439289239882
# Accuracy valid: 0.556407447973713
# Epoch: 49, loss train: 1.33, loss valid: 1.37736177444458
# Accuracy train: 0.5508390918065152
# Accuracy valid: 0.5136911281489595
# Epoch: 50, loss train: 1.15, loss valid: 1.5716581344604492
# Accuracy train: 0.5592300098716683
# Accuracy valid: 0.5388828039430449
# Epoch: 51, loss train: 1.29, loss valid: 1.4449405670166016
# Accuracy train: 0.5612043435340572
# Accuracy valid: 0.56078860898138
# Epoch: 52, loss train: 1.09, loss valid: 1.3657578229904175
# Accuracy train: 0.5538005923000987
# Accuracy valid: 0.5585980284775466
# Epoch: 53, loss train: 1.13, loss valid: 1.3984090089797974
# Accuracy train: 0.554294175715696
# Accuracy valid: 0.5585980284775466
# Epoch: 54, loss train: 1.12, loss valid: 1.0990915298461914
# Accuracy train: 0.5567620927936822
# Accuracy valid: 0.5585980284775466
# Epoch: 55, loss train: 1.17, loss valid: 1.5939922332763672
# Accuracy train: 0.5612043435340572
# Accuracy valid: 0.5618838992332968
# Epoch: 56, loss train: 1.12, loss valid: 0.9524331092834473
# Accuracy train: 0.5661401776900297
# Accuracy valid: 0.5629791894852135
# Epoch: 57, loss train: 1.13, loss valid: 1.1460158824920654
# Accuracy train: 0.5700888450148075
# Accuracy valid: 0.5640744797371303
# Epoch: 58, loss train: 1.03, loss valid: 1.6885184049606323
# Accuracy train: 0.573050345508391
# Accuracy valid: 0.5618838992332968
# Epoch: 59, loss train: 0.999, loss valid: 0.8693237900733948
# Accuracy train: 0.5769990128331688
# Accuracy valid: 0.5651697699890471
# Epoch: 60, loss train: 1.03, loss valid: 0.9151848554611206
# Accuracy train: 0.5760118460019743
# Accuracy valid: 0.5640744797371303
# Epoch: 61, loss train: 1.22, loss valid: 1.0205105543136597
# Accuracy train: 0.5809476801579467
# Accuracy valid: 0.5717415115005476
# Epoch: 62, loss train: 0.919, loss valid: 1.0456281900405884
# Accuracy train: 0.5819348469891412
# Accuracy valid: 0.5706462212486308
# Epoch: 63, loss train: 1.06, loss valid: 1.116569995880127
# Accuracy train: 0.5809476801579467
# Accuracy valid: 0.5706462212486308
# Epoch: 64, loss train: 0.985, loss valid: 0.9694027900695801
# Accuracy train: 0.5809476801579467
# Accuracy valid: 0.5739320920043811
# Epoch: 65, loss train: 1.09, loss valid: 1.083683967590332
# Accuracy train: 0.5839091806515301
# Accuracy valid: 0.5717415115005476
# Epoch: 66, loss train: 1.02, loss valid: 1.1620951890945435
# Accuracy train: 0.5844027640671273
# Accuracy valid: 0.5750273822562979
# Epoch: 67, loss train: 0.893, loss valid: 1.0344315767288208
# Accuracy train: 0.5873642645607108
# Accuracy valid: 0.5739320920043811
# Epoch: 68, loss train: 1.18, loss valid: 1.3390086889266968
# Accuracy train: 0.5927936821322803
# Accuracy valid: 0.5783132530120482
# Epoch: 69, loss train: 1.26, loss valid: 1.0671017169952393
# Accuracy train: 0.5853899308983218
# Accuracy valid: 0.5706462212486308
# Epoch: 70, loss train: 1.11, loss valid: 1.1955128908157349
# Accuracy train: 0.589832181638697
# Accuracy valid: 0.579408543263965
# Epoch: 71, loss train: 1.1, loss valid: 1.4732455015182495
# Accuracy train: 0.5927936821322803
# Accuracy valid: 0.5750273822562979
# Epoch: 72, loss train: 1.18, loss valid: 1.4210124015808105
# Accuracy train: 0.5942744323790721
# Accuracy valid: 0.579408543263965
# Epoch: 73, loss train: 1.16, loss valid: 1.1308584213256836
# Accuracy train: 0.5967423494570583
# Accuracy valid: 0.5815991237677984
# Epoch: 74, loss train: 1.28, loss valid: 1.0966408252716064
# Accuracy train: 0.5908193484698914
# Accuracy valid: 0.5772179627601315
# Epoch: 75, loss train: 1.11, loss valid: 1.2130496501922607
# Accuracy train: 0.5977295162882527
# Accuracy valid: 0.579408543263965
# Epoch: 76, loss train: 1.15, loss valid: 1.2882226705551147
# Accuracy train: 0.5977295162882527
# Accuracy valid: 0.5815991237677984
# Epoch: 77, loss train: 1.23, loss valid: 0.9037525653839111
# Accuracy train: 0.5952615992102666
# Accuracy valid: 0.579408543263965
# Epoch: 78, loss train: 1.07, loss valid: 0.9583910703659058
# Accuracy train: 0.5987166831194471
# Accuracy valid: 0.5848849945235487
# Epoch: 79, loss train: 1.06, loss valid: 0.883538544178009
# Accuracy train: 0.5987166831194471
# Accuracy valid: 0.5826944140197152
# Epoch: 80, loss train: 1.11, loss valid: 1.5655616521835327
# Accuracy train: 0.6011846001974334
# Accuracy valid: 0.583789704271632
# Epoch: 81, loss train: 1.16, loss valid: 1.1478805541992188
# Accuracy train: 0.6001974333662389
# Accuracy valid: 0.5914567360350493
# Epoch: 82, loss train: 1.0, loss valid: 1.054258942604065
# Accuracy train: 0.5977295162882527
# Accuracy valid: 0.5914567360350493
# Epoch: 83, loss train: 1.06, loss valid: 1.2281765937805176
# Accuracy train: 0.5987166831194471
# Accuracy valid: 0.5870755750273823
# Epoch: 84, loss train: 1.01, loss valid: 1.2491765022277832
# Accuracy train: 0.6051332675222113
# Accuracy valid: 0.5892661555312158
# Epoch: 85, loss train: 1.11, loss valid: 1.2139196395874023
# Accuracy train: 0.6026653504442251
# Accuracy valid: 0.5980284775465499
# Epoch: 86, loss train: 0.897, loss valid: 1.0820764303207397
# Accuracy train: 0.6036525172754196
# Accuracy valid: 0.5980284775465499
# Epoch: 87, loss train: 1.07, loss valid: 0.7535338401794434
# Accuracy train: 0.6061204343534057
# Accuracy valid: 0.6046002190580504
# Epoch: 88, loss train: 1.03, loss valid: 0.9743747711181641
# Accuracy train: 0.5982230997038499
# Accuracy valid: 0.5903614457831325
# Epoch: 89, loss train: 1.1, loss valid: 0.8991973996162415
# Accuracy train: 0.5997038499506416
# Accuracy valid: 0.5980284775465499
# Epoch: 90, loss train: 1.17, loss valid: 1.0054099559783936
# Accuracy train: 0.6085883514313919
# Accuracy valid: 0.5947426067907996
# Epoch: 91, loss train: 1.16, loss valid: 1.0787911415100098
# Accuracy train: 0.6080947680157947
# Accuracy valid: 0.6024096385542169
# Epoch: 92, loss train: 1.05, loss valid: 0.951391339302063
# Accuracy train: 0.6120434353405726
# Accuracy valid: 0.6056955093099672
# Epoch: 93, loss train: 0.889, loss valid: 1.24769127368927
# Accuracy train: 0.6120434353405726
# Accuracy valid: 0.6100766703176341
# Epoch: 94, loss train: 0.897, loss valid: 1.0333253145217896
# Accuracy train: 0.6110562685093781
# Accuracy valid: 0.6002190580503833
# Epoch: 95, loss train: 1.05, loss valid: 1.062065601348877
# Accuracy train: 0.6130306021717671
# Accuracy valid: 0.6024096385542169
# Epoch: 96, loss train: 1.09, loss valid: 1.0240803956985474
# Accuracy train: 0.6164856860809477
# Accuracy valid: 0.6035049288061336
# Epoch: 97, loss train: 1.13, loss valid: 1.5126957893371582
# Accuracy train: 0.6164856860809477
# Accuracy valid: 0.6122672508214677
# Epoch: 98, loss train: 1.0, loss valid: 0.8802554607391357
# Accuracy train: 0.6164856860809477
# Accuracy valid: 0.6078860898138007
# Epoch: 99, loss train: 1.02, loss valid: 0.7452341914176941
# Accuracy train: 0.6179664363277394
# Accuracy valid: 0.6122672508214677
# Epoch: 100, loss train: 0.953, loss valid: 1.139314889907837
# Accuracy train: 0.62142152023692
# Accuracy valid: 0.6221248630887185
# Epoch: 101, loss train: 1.05, loss valid: 1.301590085029602
# Accuracy train: 0.6179664363277394
# Accuracy valid: 0.624315443592552
# Epoch: 102, loss train: 1.04, loss valid: 1.0232460498809814
# Accuracy train: 0.5779861796643633
# Accuracy valid: 0.5750273822562979
# Epoch: 103, loss train: 0.879, loss valid: 0.9550093412399292
# Accuracy train: 0.6125370187561698
# Accuracy valid: 0.6122672508214677
# Epoch: 104, loss train: 1.04, loss valid: 1.0589450597763062
# Accuracy train: 0.6238894373149062
# Accuracy valid: 0.6221248630887185
# Epoch: 105, loss train: 1.01, loss valid: 1.024659514427185
# Accuracy train: 0.6253701875616979
# Accuracy valid: 0.624315443592552
# Epoch: 106, loss train: 1.09, loss valid: 0.9871807098388672
# Accuracy train: 0.6189536031589339
# Accuracy valid: 0.6210295728368017
# Epoch: 107, loss train: 1.02, loss valid: 0.7807655930519104
# Accuracy train: 0.6278381046396841
# Accuracy valid: 0.6265060240963856
# Epoch: 108, loss train: 1.19, loss valid: 0.9094166159629822
# Accuracy train: 0.6307996051332675
# Accuracy valid: 0.6254107338444688
# Epoch: 109, loss train: 1.01, loss valid: 1.2412983179092407
# Accuracy train: 0.6248766041461007
# Accuracy valid: 0.6232201533406353
# Epoch: 110, loss train: 0.904, loss valid: 0.7830050587654114
# Accuracy train: 0.6322803553800592
# Accuracy valid: 0.6254107338444688
# Epoch: 111, loss train: 1.1, loss valid: 1.1860705614089966
# Accuracy train: 0.6352418558736427
# Accuracy valid: 0.6276013143483024
# Epoch: 112, loss train: 1.16, loss valid: 0.7635377645492554
# Accuracy train: 0.6293188548864758
# Accuracy valid: 0.615553121577218
# Epoch: 113, loss train: 1.05, loss valid: 0.9485506415367126
# Accuracy train: 0.6322803553800592
# Accuracy valid: 0.628696604600219
# Epoch: 114, loss train: 1.1, loss valid: 1.0246624946594238
# Accuracy train: 0.6357354392892399
# Accuracy valid: 0.6265060240963856
# Epoch: 115, loss train: 1.03, loss valid: 0.819055438041687
# Accuracy train: 0.6362290227048372
# Accuracy valid: 0.628696604600219
# Epoch: 116, loss train: 1.05, loss valid: 0.8841762542724609
# Accuracy train: 0.6406712734452122
# Accuracy valid: 0.6341730558598029
# Epoch: 117, loss train: 1.15, loss valid: 1.0182849168777466
# Accuracy train: 0.6391905231984205
# Accuracy valid: 0.6319824753559693
# Epoch: 118, loss train: 1.14, loss valid: 1.1050083637237549
# Accuracy train: 0.6416584402764067
# Accuracy valid: 0.6385542168674698
# Epoch: 119, loss train: 0.973, loss valid: 1.1505299806594849
# Accuracy train: 0.6303060217176703
# Accuracy valid: 0.6232201533406353
# Epoch: 120, loss train: 0.956, loss valid: 0.8786192536354065
# Accuracy train: 0.6436327739387957
# Accuracy valid: 0.6418400876232202
# Epoch: 121, loss train: 1.01, loss valid: 1.0313526391983032
# Accuracy train: 0.6377097729516288
# Accuracy valid: 0.628696604600219
# Epoch: 122, loss train: 1.11, loss valid: 0.9761867523193359
# Accuracy train: 0.642152023692004
# Accuracy valid: 0.6385542168674698
# Epoch: 123, loss train: 0.92, loss valid: 0.8477349281311035
# Accuracy train: 0.6416584402764067
# Accuracy valid: 0.6396495071193866
# Epoch: 124, loss train: 0.848, loss valid: 0.9780335426330566
# Accuracy train: 0.6322803553800592
# Accuracy valid: 0.6385542168674698
# Epoch: 125, loss train: 1.05, loss valid: 0.9295214414596558
# Accuracy train: 0.629812438302073
# Accuracy valid: 0.6352683461117196
# Epoch: 126, loss train: 0.988, loss valid: 1.1363035440444946
# Accuracy train: 0.6470878578479763
# Accuracy valid: 0.6341730558598029
# Epoch: 127, loss train: 1.02, loss valid: 1.154040813446045
# Accuracy train: 0.6441263573543929
# Accuracy valid: 0.6374589266155531
# Epoch: 128, loss train: 1.03, loss valid: 0.9401658773422241
# Accuracy train: 0.6451135241855873
# Accuracy valid: 0.6319824753559693
# Epoch: 129, loss train: 1.05, loss valid: 0.8269498944282532
# Accuracy train: 0.6495557749259625
# Accuracy valid: 0.6407447973713034
# Epoch: 130, loss train: 1.05, loss valid: 0.6863870620727539
# Accuracy train: 0.6386969397828233
# Accuracy valid: 0.6232201533406353
# Epoch: 131, loss train: 1.08, loss valid: 0.8498044013977051
# Accuracy train: 0.6367226061204343
# Accuracy valid: 0.6265060240963856
# Epoch: 132, loss train: 1.02, loss valid: 1.2360098361968994
# Accuracy train: 0.631786771964462
# Accuracy valid: 0.6265060240963856
# Epoch: 133, loss train: 1.03, loss valid: 1.2475405931472778
# Accuracy train: 0.6480750246791708
# Accuracy valid: 0.6396495071193866
# Epoch: 134, loss train: 0.898, loss valid: 1.1257025003433228
# Accuracy train: 0.6490621915103653
# Accuracy valid: 0.6363636363636364
# Epoch: 135, loss train: 0.95, loss valid: 1.2935551404953003
# Accuracy train: 0.650542941757157
# Accuracy valid: 0.6396495071193866
# Epoch: 136, loss train: 0.915, loss valid: 1.2177696228027344
# Accuracy train: 0.6500493583415597
# Accuracy valid: 0.6418400876232202
# Epoch: 137, loss train: 1.02, loss valid: 0.7591137290000916
# Accuracy train: 0.6426456071076012
# Accuracy valid: 0.651697699890471
# Epoch: 138, loss train: 0.983, loss valid: 1.0685153007507324
# Accuracy train: 0.650542941757157
# Accuracy valid: 0.6527929901423878
# Epoch: 139, loss train: 1.04, loss valid: 1.5785597562789917
# Accuracy train: 0.6530108588351431
# Accuracy valid: 0.6484118291347207
# Epoch: 140, loss train: 0.998, loss valid: 1.017052412033081
# Accuracy train: 0.6510365251727542
# Accuracy valid: 0.6495071193866374
# Epoch: 141, loss train: 1.12, loss valid: 1.1745691299438477
# Accuracy train: 0.6549851924975321
# Accuracy valid: 0.6473165388828039
# Epoch: 142, loss train: 1.02, loss valid: 0.8120858073234558
# Accuracy train: 0.6515301085883515
# Accuracy valid: 0.6396495071193866
# Epoch: 143, loss train: 1.04, loss valid: 0.5504258871078491
# Accuracy train: 0.6525172754195459
# Accuracy valid: 0.6385542168674698
# Epoch: 144, loss train: 0.993, loss valid: 1.439122200012207
# Accuracy train: 0.6441263573543929
# Accuracy valid: 0.6363636363636364
# Epoch: 145, loss train: 0.939, loss valid: 1.012427568435669
# Accuracy train: 0.6594274432379073
# Accuracy valid: 0.6462212486308871
# Epoch: 146, loss train: 0.922, loss valid: 0.82143634557724
# Accuracy train: 0.6559723593287266
# Accuracy valid: 0.6495071193866374
# Epoch: 147, loss train: 0.945, loss valid: 0.6937251687049866
# Accuracy train: 0.6535044422507403
# Accuracy valid: 0.651697699890471
# Epoch: 148, loss train: 0.867, loss valid: 1.0015321969985962
# Accuracy train: 0.6584402764067128
# Accuracy valid: 0.6418400876232202
# Epoch: 149, loss train: 0.931, loss valid: 0.9992178678512573
# Accuracy train: 0.656959526159921
# Accuracy valid: 0.651697699890471
# Epoch: 150, loss train: 1.15, loss valid: 1.1455755233764648
# Accuracy train: 0.65893385982231
# Accuracy valid: 0.651697699890471
# Epoch: 151, loss train: 1.04, loss valid: 0.8528819680213928
# Accuracy train: 0.633761105626851
# Accuracy valid: 0.6407447973713034
# Epoch: 152, loss train: 1.05, loss valid: 1.077857255935669
# Accuracy train: 0.6584402764067128
# Accuracy valid: 0.6549835706462213
# Epoch: 153, loss train: 0.88, loss valid: 1.5784335136413574
# Accuracy train: 0.6530108588351431
# Accuracy valid: 0.6418400876232202
# Epoch: 154, loss train: 0.877, loss valid: 0.8595165610313416
# Accuracy train: 0.6618953603158934
# Accuracy valid: 0.6506024096385542
# Epoch: 155, loss train: 1.07, loss valid: 0.8881618976593018
# Accuracy train: 0.6574531095755183
# Accuracy valid: 0.6506024096385542
# Epoch: 156, loss train: 0.984, loss valid: 0.6313368082046509
# Accuracy train: 0.65893385982231
# Accuracy valid: 0.6451259583789705
# Epoch: 157, loss train: 1.0, loss valid: 1.0341119766235352
# Accuracy train: 0.6554787759131293
# Accuracy valid: 0.6462212486308871
# Epoch: 158, loss train: 0.962, loss valid: 0.8184520602226257
# Accuracy train: 0.6564659427443238
# Accuracy valid: 0.651697699890471
# Epoch: 159, loss train: 0.763, loss valid: 0.8485425710678101
# Accuracy train: 0.6530108588351431
# Accuracy valid: 0.6495071193866374
# Epoch: 160, loss train: 0.971, loss valid: 1.552632212638855
# Accuracy train: 0.6618953603158934
# Accuracy valid: 0.6506024096385542
# Epoch: 161, loss train: 1.01, loss valid: 0.7808672785758972
# Accuracy train: 0.6648568608094768
# Accuracy valid: 0.6506024096385542
# Epoch: 162, loss train: 0.763, loss valid: 0.8366749882698059
# Accuracy train: 0.6648568608094768
# Accuracy valid: 0.651697699890471
# Epoch: 163, loss train: 0.96, loss valid: 1.0851755142211914
# Accuracy train: 0.6653504442250741
# Accuracy valid: 0.6495071193866374
# Epoch: 164, loss train: 0.938, loss valid: 0.5546691417694092
# Accuracy train: 0.6628825271470878
# Accuracy valid: 0.6527929901423878
# Epoch: 165, loss train: 0.918, loss valid: 0.974959671497345
# Accuracy train: 0.6658440276406713
# Accuracy valid: 0.6495071193866374
# Epoch: 166, loss train: 0.978, loss valid: 1.0518474578857422
# Accuracy train: 0.6554787759131293
# Accuracy valid: 0.6495071193866374
# Epoch: 167, loss train: 0.892, loss valid: 0.7566044330596924
# Accuracy train: 0.6638696939782823
# Accuracy valid: 0.651697699890471
# Epoch: 168, loss train: 0.983, loss valid: 1.0612101554870605
# Accuracy train: 0.6609081934846989
# Accuracy valid: 0.651697699890471
# Epoch: 169, loss train: 0.926, loss valid: 1.3228728771209717
# Accuracy train: 0.6559723593287266
# Accuracy valid: 0.6462212486308871
# Epoch: 170, loss train: 1.01, loss valid: 1.1403595209121704
# Accuracy train: 0.6539980256663376
# Accuracy valid: 0.6473165388828039
# Epoch: 171, loss train: 0.945, loss valid: 0.9171032905578613
# Accuracy train: 0.6618953603158934
# Accuracy valid: 0.6549835706462213
# Epoch: 172, loss train: 0.877, loss valid: 0.9867323637008667
# Accuracy train: 0.6628825271470878
# Accuracy valid: 0.6506024096385542
# Epoch: 173, loss train: 0.955, loss valid: 1.273162603378296
# Accuracy train: 0.6638696939782823
# Accuracy valid: 0.6538882803943045
# Epoch: 174, loss train: 0.955, loss valid: 0.7430600523948669
# Accuracy train: 0.6623889437314906
# Accuracy valid: 0.651697699890471
# Epoch: 175, loss train: 1.04, loss valid: 1.1933186054229736
# Accuracy train: 0.6614017769002961
# Accuracy valid: 0.656078860898138
# Epoch: 176, loss train: 1.13, loss valid: 1.3758341073989868
# Accuracy train: 0.6406712734452122
# Accuracy valid: 0.6462212486308871
# Epoch: 177, loss train: 0.91, loss valid: 1.0144802331924438
# Accuracy train: 0.6535044422507403
# Accuracy valid: 0.6473165388828039
# Epoch: 178, loss train: 0.963, loss valid: 0.9701104164123535
# Accuracy train: 0.6623889437314906
# Accuracy valid: 0.6462212486308871
# Epoch: 179, loss train: 1.22, loss valid: 0.8840582370758057
# Accuracy train: 0.6663376110562685
# Accuracy valid: 0.6538882803943045
# Epoch: 180, loss train: 0.988, loss valid: 0.5897381901741028
# Accuracy train: 0.6584402764067128
# Accuracy valid: 0.6549835706462213
# Epoch: 181, loss train: 0.956, loss valid: 0.5432776212692261
# Accuracy train: 0.6633761105626851
# Accuracy valid: 0.6506024096385542
# Epoch: 182, loss train: 0.825, loss valid: 1.0360493659973145
# Accuracy train: 0.6633761105626851
# Accuracy valid: 0.6549835706462213
# Epoch: 183, loss train: 0.892, loss valid: 1.3247888088226318
# Accuracy train: 0.6623889437314906
# Accuracy valid: 0.6549835706462213
# Epoch: 184, loss train: 0.986, loss valid: 0.7822826504707336
# Accuracy train: 0.6638696939782823
# Accuracy valid: 0.6527929901423878
# Epoch: 185, loss train: 1.09, loss valid: 0.9531472325325012
# Accuracy train: 0.6574531095755183
# Accuracy valid: 0.6495071193866374
# Epoch: 186, loss train: 1.01, loss valid: 0.7841068506240845
# Accuracy train: 0.6653504442250741
# Accuracy valid: 0.6571741511500547
# Epoch: 187, loss train: 0.92, loss valid: 1.049423098564148
# Accuracy train: 0.6599210266535045
# Accuracy valid: 0.6538882803943045
# Epoch: 188, loss train: 0.8, loss valid: 1.2996293306350708
# Accuracy train: 0.6633761105626851
# Accuracy valid: 0.6549835706462213
# Epoch: 189, loss train: 0.958, loss valid: 1.4041004180908203
# Accuracy train: 0.6559723593287266
# Accuracy valid: 0.6484118291347207
# Epoch: 190, loss train: 0.926, loss valid: 0.5693020820617676
# Accuracy train: 0.6618953603158934
# Accuracy valid: 0.6549835706462213
# Epoch: 191, loss train: 0.74, loss valid: 1.0743989944458008
# Accuracy train: 0.6628825271470878
# Accuracy valid: 0.6506024096385542
# Epoch: 192, loss train: 0.895, loss valid: 1.1627322435379028
# Accuracy train: 0.6638696939782823
# Accuracy valid: 0.6527929901423878
# Epoch: 193, loss train: 0.823, loss valid: 1.0924323797225952
# Accuracy train: 0.6525172754195459
# Accuracy valid: 0.6527929901423878
# Epoch: 194, loss train: 0.736, loss valid: 0.7702522277832031
# Accuracy train: 0.6633761105626851
# Accuracy valid: 0.6473165388828039
# Epoch: 195, loss train: 0.961, loss valid: 0.5871483087539673
# Accuracy train: 0.6638696939782823
# Accuracy valid: 0.651697699890471
# Epoch: 196, loss train: 0.989, loss valid: 0.8917406797409058
# Accuracy train: 0.6638696939782823
# Accuracy valid: 0.6527929901423878
# Epoch: 197, loss train: 1.08, loss valid: 1.101456642150879
# Accuracy train: 0.6653504442250741
# Accuracy valid: 0.651697699890471
# Epoch: 198, loss train: 1.04, loss valid: 1.0701076984405518
# Accuracy train: 0.6633761105626851
# Accuracy valid: 0.6571741511500547
# Epoch: 199, loss train: 0.968, loss valid: 1.2446887493133545
# Accuracy train: 0.6643632773938796
# Accuracy valid: 0.6571741511500547

# %%
train_loss = [x.cpu() for x in train_loss]
valid_loss = [x.cpu() for x in valid_loss]
plot_metrics(train_loss, valid_loss, train_acc, valid_acc)
# Out:
# Final Training Accuracy: 0.6643632773938796
# Final Validation Accuracy: 0.6571741511500547

# %%
model = LSTM_Seq_Regressor(1, 100, 1, 5, bidirectional=True).to(device)
train_loss = []
valid_loss = []
train_acc = []
valid_acc = []
train_model(model, train_loader, valid_loader, train_loss, valid_loss, train_acc, valid_acc, learning_rate=0.001)
# Out:
# Epoch: 0, loss train: 1.79, loss valid: 1.7044988870620728
# Accuracy train: 0.5513326752221125
# Accuracy valid: 0.556407447973713
# Epoch: 1, loss train: 1.43, loss valid: 1.7653684616088867
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5585980284775466
# Epoch: 2, loss train: 1.26, loss valid: 1.3409425020217896
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 3, loss train: 1.29, loss valid: 1.0173066854476929
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 4, loss train: 1.21, loss valid: 1.0177935361862183
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 5, loss train: 1.28, loss valid: 1.1148194074630737
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 6, loss train: 1.17, loss valid: 1.4754726886749268
# Accuracy train: 0.5533070088845015
# Accuracy valid: 0.5575027382256298
# Epoch: 7, loss train: 1.13, loss valid: 1.090926170349121
# Accuracy train: 0.5656465942744324
# Accuracy valid: 0.56078860898138
# Epoch: 8, loss train: 1.3, loss valid: 1.4505177736282349
# Accuracy train: 0.5631786771964462
# Accuracy valid: 0.5673603504928806
# Epoch: 9, loss train: 1.14, loss valid: 1.260074496269226
# Accuracy train: 0.5745310957551826
# Accuracy valid: 0.5750273822562979
# Epoch: 10, loss train: 0.997, loss valid: 0.6964216828346252
# Accuracy train: 0.5844027640671273
# Accuracy valid: 0.5783132530120482
# Epoch: 11, loss train: 1.01, loss valid: 0.9651864171028137
# Accuracy train: 0.5908193484698914
# Accuracy valid: 0.5892661555312158
# Epoch: 12, loss train: 1.06, loss valid: 1.3236284255981445
# Accuracy train: 0.587857847976308
# Accuracy valid: 0.6024096385542169
# Epoch: 13, loss train: 0.977, loss valid: 1.0197511911392212
# Accuracy train: 0.6016781836130306
# Accuracy valid: 0.5914567360350493
# Epoch: 14, loss train: 0.961, loss valid: 0.9723433256149292
# Accuracy train: 0.5853899308983218
# Accuracy valid: 0.5695509309967142
# Epoch: 15, loss train: 1.07, loss valid: 1.003791093826294
# Accuracy train: 0.6174728529121422
# Accuracy valid: 0.6122672508214677
# Epoch: 16, loss train: 1.07, loss valid: 0.886748194694519
# Accuracy train: 0.6219151036525172
# Accuracy valid: 0.6210295728368017
# Epoch: 17, loss train: 0.959, loss valid: 1.1066113710403442
# Accuracy train: 0.623395853899309
# Accuracy valid: 0.6330777656078861
# Epoch: 18, loss train: 1.0, loss valid: 0.8639600872993469
# Accuracy train: 0.6224086870681145
# Accuracy valid: 0.6232201533406353
# Epoch: 19, loss train: 1.0, loss valid: 1.000104308128357
# Accuracy train: 0.6273445212240869
# Accuracy valid: 0.6276013143483024
# Epoch: 20, loss train: 0.987, loss valid: 0.9136661887168884
# Accuracy train: 0.6372161895360315
# Accuracy valid: 0.6166484118291348
# Epoch: 21, loss train: 1.06, loss valid: 1.0991309881210327
# Accuracy train: 0.6362290227048372
# Accuracy valid: 0.6232201533406353
# Epoch: 22, loss train: 1.01, loss valid: 0.8352294564247131
# Accuracy train: 0.6426456071076012
# Accuracy valid: 0.6385542168674698
# Epoch: 23, loss train: 1.08, loss valid: 1.0908119678497314
# Accuracy train: 0.6372161895360315
# Accuracy valid: 0.6297918948521358
# Epoch: 24, loss train: 1.05, loss valid: 0.8188506960868835
# Accuracy train: 0.6441263573543929
# Accuracy valid: 0.6571741511500547
# Epoch: 25, loss train: 1.05, loss valid: 1.2099003791809082
# Accuracy train: 0.6174728529121422
# Accuracy valid: 0.6308871851040526
# Epoch: 26, loss train: 0.79, loss valid: 0.656069815158844
# Accuracy train: 0.6426456071076012
# Accuracy valid: 0.6385542168674698
# Epoch: 27, loss train: 0.979, loss valid: 1.168393850326538
# Accuracy train: 0.65893385982231
# Accuracy valid: 0.6484118291347207
# Epoch: 28, loss train: 0.963, loss valid: 0.9543722867965698
# Accuracy train: 0.6549851924975321
# Accuracy valid: 0.6626506024096386
# Epoch: 29, loss train: 1.01, loss valid: 0.9467052221298218
# Accuracy train: 0.6510365251727542
# Accuracy valid: 0.6538882803943045
# Epoch: 30, loss train: 0.885, loss valid: 1.3636224269866943
# Accuracy train: 0.6638696939782823
# Accuracy valid: 0.6637458926615553
# Epoch: 31, loss train: 0.885, loss valid: 0.8437598943710327
# Accuracy train: 0.6549851924975321
# Accuracy valid: 0.6582694414019715
# Epoch: 32, loss train: 0.826, loss valid: 1.0975896120071411
# Accuracy train: 0.6535044422507403
# Accuracy valid: 0.6626506024096386
# Epoch: 33, loss train: 0.896, loss valid: 0.7712419033050537
# Accuracy train: 0.6604146100691016
# Accuracy valid: 0.6484118291347207
# Epoch: 34, loss train: 1.02, loss valid: 0.8374508023262024
# Accuracy train: 0.6539980256663376
# Accuracy valid: 0.6308871851040526
# Epoch: 35, loss train: 0.923, loss valid: 0.7679514288902283
# Accuracy train: 0.6791707798617966
# Accuracy valid: 0.6736035049288062
# Epoch: 36, loss train: 0.724, loss valid: 0.6445831060409546
# Accuracy train: 0.6796643632773939
# Accuracy valid: 0.6593647316538883
# Epoch: 37, loss train: 0.693, loss valid: 1.2586368322372437
# Accuracy train: 0.6880552813425469
# Accuracy valid: 0.6746987951807228
# Epoch: 38, loss train: 0.899, loss valid: 0.7526230812072754
# Accuracy train: 0.6806515301085884
# Accuracy valid: 0.6768893756845564
# Epoch: 39, loss train: 0.769, loss valid: 0.4739513397216797
# Accuracy train: 0.6831194471865746
# Accuracy valid: 0.6659364731653888
# Epoch: 40, loss train: 0.783, loss valid: 0.9924660921096802
# Accuracy train: 0.6910167818361304
# Accuracy valid: 0.6757940854326396
# Epoch: 41, loss train: 0.67, loss valid: 0.8337519764900208
# Accuracy train: 0.6796643632773939
# Accuracy valid: 0.6549835706462213
# Epoch: 42, loss train: 0.837, loss valid: 1.0263252258300781
# Accuracy train: 0.6900296150049359
# Accuracy valid: 0.6757940854326396
# Epoch: 43, loss train: 0.742, loss valid: 0.7828007340431213
# Accuracy train: 0.6984205330700889
# Accuracy valid: 0.6725082146768894
# Epoch: 44, loss train: 0.884, loss valid: 1.0764871835708618
# Accuracy train: 0.6959526159921027
# Accuracy valid: 0.6889375684556407
# Epoch: 45, loss train: 0.815, loss valid: 1.0318259000778198
# Accuracy train: 0.700888450148075
# Accuracy valid: 0.6670317634173056
# Epoch: 46, loss train: 0.894, loss valid: 1.17306649684906
# Accuracy train: 0.7018756169792695
# Accuracy valid: 0.6593647316538883
# Epoch: 47, loss train: 0.909, loss valid: 0.8629215955734253
# Accuracy train: 0.7137216189536032
# Accuracy valid: 0.6845564074479737
# Epoch: 48, loss train: 0.747, loss valid: 0.931699812412262
# Accuracy train: 0.7152023692003948
# Accuracy valid: 0.6922234392113911
# Epoch: 49, loss train: 0.945, loss valid: 0.6695584654808044
# Accuracy train: 0.6989141164856861
# Accuracy valid: 0.6768893756845564
# Epoch: 50, loss train: 0.959, loss valid: 1.0649614334106445
# Accuracy train: 0.700888450148075
# Accuracy valid: 0.6801752464403067
# Epoch: 51, loss train: 0.813, loss valid: 0.9430956840515137
# Accuracy train: 0.7142152023692004
# Accuracy valid: 0.6768893756845564
# Epoch: 52, loss train: 0.838, loss valid: 1.121228814125061
# Accuracy train: 0.6702862783810464
# Accuracy valid: 0.6681270536692223
# Epoch: 53, loss train: 0.668, loss valid: 0.9073492884635925
# Accuracy train: 0.7043435340572557
# Accuracy valid: 0.6593647316538883
# Epoch: 54, loss train: 0.742, loss valid: 0.7418074607849121
# Accuracy train: 0.7097729516288253
# Accuracy valid: 0.6845564074479737
# Epoch: 55, loss train: 0.617, loss valid: 0.5639790892601013
# Accuracy train: 0.7171767028627838
# Accuracy valid: 0.6757940854326396
# Epoch: 56, loss train: 0.727, loss valid: 0.8394613265991211
# Accuracy train: 0.7097729516288253
# Accuracy valid: 0.6823658269441402
# Epoch: 57, loss train: 0.752, loss valid: 0.7066408395767212
# Accuracy train: 0.711253701875617
# Accuracy valid: 0.664841182913472
# Epoch: 58, loss train: 0.752, loss valid: 1.1511940956115723
# Accuracy train: 0.6811451135241856
# Accuracy valid: 0.6484118291347207
# Epoch: 59, loss train: 0.785, loss valid: 0.8336517214775085
# Accuracy train: 0.6910167818361304
# Accuracy valid: 0.6703176341730559
# Epoch: 60, loss train: 0.801, loss valid: 0.4889715909957886
# Accuracy train: 0.702862783810464
# Accuracy valid: 0.6757940854326396
# Epoch: 61, loss train: 0.749, loss valid: 0.8480919003486633
# Accuracy train: 0.713228035538006
# Accuracy valid: 0.6757940854326396
# Epoch: 62, loss train: 0.907, loss valid: 0.5390915870666504
# Accuracy train: 0.7082922013820335
# Accuracy valid: 0.6900328587075575
# Epoch: 63, loss train: 0.796, loss valid: 0.7940019369125366
# Accuracy train: 0.6989141164856861
# Accuracy valid: 0.6845564074479737
# Epoch: 64, loss train: 0.817, loss valid: 0.6544127464294434
# Accuracy train: 0.6974333662388944
# Accuracy valid: 0.687842278203724
# Epoch: 65, loss train: 0.684, loss valid: 0.5836359262466431
# Accuracy train: 0.7152023692003948
# Accuracy valid: 0.6790799561883899
# Epoch: 66, loss train: 0.764, loss valid: 0.6564497947692871
# Accuracy train: 0.7147087857847977
# Accuracy valid: 0.6812705366922235
# Epoch: 67, loss train: 0.847, loss valid: 0.6913756728172302
# Accuracy train: 0.7201382033563672
# Accuracy valid: 0.6736035049288062
# Epoch: 68, loss train: 0.787, loss valid: 1.1503087282180786
# Accuracy train: 0.7285291214215203
# Accuracy valid: 0.687842278203724
# Epoch: 69, loss train: 0.852, loss valid: 0.8415618538856506
# Accuracy train: 0.713228035538006
# Accuracy valid: 0.6681270536692223
# Epoch: 70, loss train: 0.813, loss valid: 0.7260476350784302
# Accuracy train: 0.7290227048371175
# Accuracy valid: 0.6812705366922235
# Epoch: 71, loss train: 0.683, loss valid: 0.5850405693054199
# Accuracy train: 0.7137216189536032
# Accuracy valid: 0.6659364731653888
# Epoch: 72, loss train: 0.607, loss valid: 1.0176666975021362
# Accuracy train: 0.700888450148075
# Accuracy valid: 0.6692223439211391
# Epoch: 73, loss train: 0.776, loss valid: 1.1751251220703125
# Accuracy train: 0.71964461994077
# Accuracy valid: 0.6790799561883899
# Epoch: 74, loss train: 0.862, loss valid: 0.7784953117370605
# Accuracy train: 0.71964461994077
# Accuracy valid: 0.683461117196057
# Epoch: 75, loss train: 0.941, loss valid: 1.2854316234588623
# Accuracy train: 0.7240868706811451
# Accuracy valid: 0.6801752464403067
# Epoch: 76, loss train: 0.944, loss valid: 0.8602762818336487
# Accuracy train: 0.6929911154985192
# Accuracy valid: 0.6462212486308871
# Epoch: 77, loss train: 0.836, loss valid: 1.0108219385147095
# Accuracy train: 0.7255676209279368
# Accuracy valid: 0.6987951807228916
# Epoch: 78, loss train: 0.692, loss valid: 0.9020969867706299
# Accuracy train: 0.7309970384995064
# Accuracy valid: 0.6976998904709748
# Epoch: 79, loss train: 0.679, loss valid: 0.6131306886672974
# Accuracy train: 0.7097729516288253
# Accuracy valid: 0.6484118291347207
# Epoch: 80, loss train: 0.787, loss valid: 1.139809250831604
# Accuracy train: 0.7309970384995064
# Accuracy valid: 0.6933187294633077
# Epoch: 81, loss train: 0.71, loss valid: 0.9010637998580933
# Accuracy train: 0.7324777887462981
# Accuracy valid: 0.696604600219058
# Epoch: 82, loss train: 0.739, loss valid: 0.7029061913490295
# Accuracy train: 0.7388943731490621
# Accuracy valid: 0.6987951807228916
# Epoch: 83, loss train: 0.729, loss valid: 0.9059574604034424
# Accuracy train: 0.7339585389930898
# Accuracy valid: 0.7097480832420592
# Epoch: 84, loss train: 0.836, loss valid: 1.236434817314148
# Accuracy train: 0.7221125370187562
# Accuracy valid: 0.6911281489594743
# Epoch: 85, loss train: 0.737, loss valid: 0.8698115348815918
# Accuracy train: 0.7166831194471865
# Accuracy valid: 0.6955093099671413
# Epoch: 86, loss train: 0.841, loss valid: 0.8519104719161987
# Accuracy train: 0.7359328726554788
# Accuracy valid: 0.6987951807228916
# Epoch: 87, loss train: 0.806, loss valid: 0.905688464641571
# Accuracy train: 0.7423494570582428
# Accuracy valid: 0.7108433734939759
# Epoch: 88, loss train: 0.692, loss valid: 0.9708272218704224
# Accuracy train: 0.7359328726554788
# Accuracy valid: 0.7009857612267251
# Epoch: 89, loss train: 0.824, loss valid: 0.7416505217552185
# Accuracy train: 0.7305034550839091
# Accuracy valid: 0.6955093099671413
# Epoch: 90, loss train: 0.701, loss valid: 0.6615492105484009
# Accuracy train: 0.7423494570582428
# Accuracy valid: 0.7086527929901424
# Epoch: 91, loss train: 0.634, loss valid: 0.5610799193382263
# Accuracy train: 0.7334649555774926
# Accuracy valid: 0.7108433734939759
# Epoch: 92, loss train: 0.748, loss valid: 0.6985713243484497
# Accuracy train: 0.7324777887462981
# Accuracy valid: 0.7064622124863089
# Epoch: 93, loss train: 0.691, loss valid: 0.5853827595710754
# Accuracy train: 0.7502467917077986
# Accuracy valid: 0.6998904709748083
# Epoch: 94, loss train: 0.74, loss valid: 1.1961567401885986
# Accuracy train: 0.7374136229022705
# Accuracy valid: 0.7020810514786419
# Epoch: 95, loss train: 0.757, loss valid: 0.9133267998695374
# Accuracy train: 0.7541954590325765
# Accuracy valid: 0.7119386637458927
# Epoch: 96, loss train: 0.701, loss valid: 0.9562604427337646
# Accuracy train: 0.7532082922013821
# Accuracy valid: 0.7207009857612268
# Epoch: 97, loss train: 0.941, loss valid: 1.2405595779418945
# Accuracy train: 0.7379072063178678
# Accuracy valid: 0.687842278203724
# Epoch: 98, loss train: 0.637, loss valid: 0.6483480334281921
# Accuracy train: 0.7453109575518263
# Accuracy valid: 0.6987951807228916
# Epoch: 99, loss train: 0.815, loss valid: 0.6426689028739929
# Accuracy train: 0.7467917077986179
# Accuracy valid: 0.7020810514786419
# Epoch: 100, loss train: 0.608, loss valid: 0.8439348340034485
# Accuracy train: 0.7492596248766041
# Accuracy valid: 0.7053669222343921
# Epoch: 101, loss train: 0.642, loss valid: 0.7147139310836792
# Accuracy train: 0.7462981243830207
# Accuracy valid: 0.7097480832420592
# Epoch: 102, loss train: 0.793, loss valid: 0.8894692659378052
# Accuracy train: 0.7532082922013821
# Accuracy valid: 0.7108433734939759
# Epoch: 103, loss train: 0.718, loss valid: 0.9909941554069519
# Accuracy train: 0.7384007897334649
# Accuracy valid: 0.6933187294633077
# Epoch: 104, loss train: 0.812, loss valid: 1.0229134559631348
# Accuracy train: 0.7502467917077986
# Accuracy valid: 0.7053669222343921
# Epoch: 105, loss train: 0.812, loss valid: 0.8991342782974243
# Accuracy train: 0.736426456071076
# Accuracy valid: 0.6856516976998904
# Epoch: 106, loss train: 0.662, loss valid: 0.6292650103569031
# Accuracy train: 0.7517275419545904
# Accuracy valid: 0.7064622124863089
# Epoch: 107, loss train: 0.619, loss valid: 0.8591699600219727
# Accuracy train: 0.7482724580454096
# Accuracy valid: 0.7130339539978094
# Epoch: 108, loss train: 0.741, loss valid: 1.0092557668685913
# Accuracy train: 0.7561697926949654
# Accuracy valid: 0.6987951807228916
# Epoch: 109, loss train: 0.64, loss valid: 0.9107906222343445
# Accuracy train: 0.726061204343534
# Accuracy valid: 0.687842278203724
# Epoch: 110, loss train: 0.748, loss valid: 1.0105886459350586
# Accuracy train: 0.7379072063178678
# Accuracy valid: 0.7020810514786419
# Epoch: 111, loss train: 0.772, loss valid: 1.3629553318023682
# Accuracy train: 0.7458045409674235
# Accuracy valid: 0.7031763417305587
# Epoch: 112, loss train: 0.637, loss valid: 1.9332687854766846
# Accuracy train: 0.7546890424481737
# Accuracy valid: 0.7119386637458927
# Epoch: 113, loss train: 0.656, loss valid: 0.8750747442245483
# Accuracy train: 0.7625863770977295
# Accuracy valid: 0.7130339539978094
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[115], line 6
#       4 train_acc = []
#       5 valid_acc = []
# ----> 6 train_model(model, train_loader, valid_loader, train_loss, valid_loss, train_acc, valid_acc, learning_rate=0.001)
#
# Cell In[90], line 33, in train_model(model, train_loader, valid_loader, train_loss, valid_loss, train_acc, valid_acc, learning_rate, epoch_number)
#      31 # if epoch % 10 == 0:
#      32 acc_valid, loss_valid = eval(valid_loader, model)
# ---> 33 acc_train, loss_train = eval(train_loader, model)
#      34 train_loss.append(loss_train)
#      35 valid_loss.append(loss_valid)
#
# Cell In[81], line 17, in eval(loader, net)
#      14 hidden, state = hidden.to(device), state.to(device)
#      16 x_packed = pack_padded_sequence(x, x_len, batch_first=True, enforce_sorted=False)
# ---> 17 preds_packed, _ = model(x_packed, (hidden, state))
#      18 preds, pred_len = pad_packed_sequence(preds_packed, batch_first=True, padding_value=pad)
#      20 preds = preds.squeeze(2)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[113], line 22, in LSTM_Seq_Regressor.forward(self, x, hidden)
#      21 def forward(self, x, hidden):
# ---> 22     all_outputs, hidden = self.lstm(x, hidden)
#      23     return all_outputs, hidden
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:815, in LSTM.forward(self, input, hx)
#     812     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     813                       self.dropout, self.training, self.bidirectional, self.batch_first)
#     814 else:
# --> 815     result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     816                       self.num_layers, self.dropout, self.training, self.bidirectional)
#     817 output = result[0]
#     818 hidden = result[1:]
#
# KeyboardInterrupt:

# %%
train_loss = [x.cpu() for x in train_loss]
valid_loss = [x.cpu() for x in valid_loss]
plot_metrics(train_loss, valid_loss, train_acc, valid_acc)
# Out:
# Final Training Accuracy: 0.7625863770977295
# Final Validation Accuracy: 0.7130339539978094

# %% [markdown]
# ### Model (do poprawy)

# %%
num_of_columns_without_classes = 50

class LSTMRegressor(nn.Module):

    def __init__(self, input_size, hidden_size, num_layers, out_size, bidirectional = False):
        super().__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        if bidirectional:
            self.bidirectional = 2
        else:
            self.bidirectional = 1
        self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_size, num_layers = num_layers, bidirectional=bidirectional, dropout=0.4)
        self.fc = nn.Linear(hidden_size*num_of_columns_without_classes*self.bidirectional, out_size)

    def init_hidden(self, batch_size):
        hidden = torch.zeros(self.num_layers*self.bidirectional , batch_size, self.hidden_size)
        state = torch.zeros(self.num_layers*self.bidirectional , batch_size, self.hidden_size)
        return hidden, state

    def forward(self, x, hidden):
        x = torch.transpose(x,0,1)
        all_outputs, hidden = self.lstm(x, hidden)
        all_outputs = torch.transpose(all_outputs,0,1)
        out = torch.flatten(all_outputs,1)
        x = self.fc(out)
        return x, hidden

model = LSTMRegressor(1,5,2,1).to(device)
model
# Out:
# LSTMRegressor(
#   (lstm): LSTM(1, 5, num_layers=2, dropout=0.4)
#   (fc): Linear(in_features=250, out_features=1, bias=True)
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
loss_fun = nn.CrossEntropyLoss()

# Training loop
for epoch in range(101):
    for x, targets in train_loader:
        print(f"AAA: {type(targets)}")
        x = x.to(device).unsqueeze(2)
#         x = x.unsqueeze(2)
        targets = targets.to(device)
        hidden, state = model.init_hidden(x.size(0))
        hidden, state = hidden.to(device), state.to(device)
        preds, _ = model(x, (hidden,state))
        preds = preds.squeeze(1)
        optimizer.zero_grad()
        loss = loss_fun(preds, targets)
        loss.backward()
        optimizer.step()
    if epoch % 10 == 0:
        print(f"Epoch: {epoch}, loss: {loss.item():.3}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 6
#       4 # Training loop
#       5 for epoch in range(101):
# ----> 6     for x, targets in train_loader:
#       7         print(f"AAA: {type(targets)}")
#       8         x = x.to(device).unsqueeze(2)
#
# ValueError: too many values to unpack (expected 2)

# %%
# with torch.no_grad():
#     hidden, state = model.init_hidden(len(test_data))
#     hidden, state = hidden.to(device), state.to(device)
#     preds,_ =  model(test_data.to(device).unsqueeze(2), (hidden,state))
# print(f"Accuracy: {(torch.argmax(preds,1).cpu()==test_targets).sum().item()/len(test_targets):.3}")

# %% [markdown]
# ## Trenowanie od nowa

# %% [markdown]
# ## Trenowanie modelu dla oversamplingu

# %%
samples_weights_train = compute_classes_weights(classes_train)
samples_weights_valid = compute_classes_weights(classes_valid)

# %%
sampler_train = torch.utils.data.WeightedRandomSampler(samples_weights_train, len(samples_weights_train), replacement=True)
sampler_valid = torch.utils.data.WeightedRandomSampler(samples_weights_valid, len(samples_weights_valid), replacement=True)
train_loader = DataLoader(train_set, batch_size=64, collate_fn=pad_collate, sampler=sampler_train)
valid_loader = DataLoader(valid_set, batch_size=64, collate_fn=pad_collate, sampler=sampler_valid)

# %%
model = LSTM_Seq_Regressor(1, 40, 2, 5, bidirectional=False, drop_out=0.3).to(device)
train_loss = []
valid_loss = []
train_acc = []
valid_acc = []

# %%
train_model(model, train_loader, valid_loader, train_loss, valid_loss, train_acc, valid_acc, learning_rate=0.002)
# Out:
# Epoch: 0, loss train: 0.894, loss valid: 1.2151155471801758
# Accuracy train: 0.6554787759131293
# Accuracy valid: 0.5629791894852135
# Epoch: 10, loss train: 0.887, loss valid: 1.3185776472091675
# Accuracy train: 0.6791707798617966
# Accuracy valid: 0.5706462212486308
# Epoch: 20, loss train: 0.92, loss valid: 0.8192285299301147
# Accuracy train: 0.6253701875616979
# Accuracy valid: 0.5334063526834611
# Epoch: 30, loss train: 0.823, loss valid: 0.8957592248916626
# Accuracy train: 0.6510365251727542
# Accuracy valid: 0.5772179627601315
# Epoch: 40, loss train: 1.01, loss valid: 1.0376639366149902
# Accuracy train: 0.6515301085883515
# Accuracy valid: 0.5662650602409639
# Epoch: 50, loss train: 1.16, loss valid: 1.0977438688278198
# Accuracy train: 0.6411648568608095
# Accuracy valid: 0.579408543263965
# Epoch: 60, loss train: 0.716, loss valid: 0.9331713318824768
# Accuracy train: 0.6732477788746298
# Accuracy valid: 0.588170865279299
# Epoch: 70, loss train: 0.944, loss valid: 1.2523932456970215
# Accuracy train: 0.6623889437314906
# Accuracy valid: 0.6144578313253012
# Epoch: 80, loss train: 0.81, loss valid: 0.8708271384239197
# Accuracy train: 0.6510365251727542
# Accuracy valid: 0.5191675794085433
# Epoch: 90, loss train: 0.923, loss valid: 0.942523717880249
# Accuracy train: 0.6604146100691016
# Accuracy valid: 0.5761226725082147
# Epoch: 100, loss train: 0.655, loss valid: 1.3932048082351685
# Accuracy train: 0.6831194471865746
# Accuracy valid: 0.5618838992332968
# Epoch: 110, loss train: 0.68, loss valid: 1.2423374652862549
# Accuracy train: 0.6480750246791708
# Accuracy valid: 0.5805038335158818
# Epoch: 120, loss train: 0.972, loss valid: 1.2644269466400146
# Accuracy train: 0.6776900296150049
# Accuracy valid: 0.5345016429353778
# Epoch: 130, loss train: 0.988, loss valid: 1.7221853733062744
# Accuracy train: 0.6860809476801579
# Accuracy valid: 0.5914567360350493
# Epoch: 140, loss train: 0.775, loss valid: 0.9572349786758423
# Accuracy train: 0.6860809476801579
# Accuracy valid: 0.5684556407447974
# Epoch: 150, loss train: 1.04, loss valid: 1.5539408922195435
# Accuracy train: 0.6638696939782823
# Accuracy valid: 0.5728368017524644
# Epoch: 160, loss train: 0.922, loss valid: 1.218836784362793
# Accuracy train: 0.6732477788746298
# Accuracy valid: 0.6024096385542169
# Epoch: 170, loss train: 0.934, loss valid: 1.406698226928711
# Accuracy train: 0.6870681145113524
# Accuracy valid: 0.5399780941949617
# Epoch: 180, loss train: 0.888, loss valid: 1.2801908254623413
# Accuracy train: 0.7023692003948667
# Accuracy valid: 0.579408543263965
# Epoch: 190, loss train: 0.9, loss valid: 1.2013503313064575
# Accuracy train: 0.6880552813425469
# Accuracy valid: 0.5443592552026287

# %%
train_loss = [x.cpu() for x in train_loss]
valid_loss = [x.cpu() for x in valid_loss]
plot_metrics(train_loss, valid_loss, train_acc, valid_acc)
# Out:
# Final Training Accuracy: 0.6880552813425469
# Final Validation Accuracy: 0.5443592552026287
